-- %%
-- Validación de conteos entre capas (Punto 2)
SELECT 'Bronze' as capa, count(*) as total FROM bootcamp_gabriel.bronze.properties_bronze
UNION ALL
SELECT 'Silver' as capa, count(*) as total FROM bootcamp_gabriel.silver.properties_silver
UNION ALL
SELECT 'Gold_Fact' as capa, count(*) as total FROM bootcamp_gabriel.gold.fact_ventas;

-- Verificación de la métrica calculada (Punto 3)
SELECT * FROM bootcamp_gabriel.gold.fact_ventas 
WHERE precio_m2 IS NOT NULL 
LIMIT 10;
