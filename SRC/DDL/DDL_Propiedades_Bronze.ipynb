-- %%
DROP TABLE IF EXISTS bootcamp_gabriel.bronze.properties_bronze;

CREATE TABLE bootcamp_gabriel.bronze.properties_bronze
USING CSV
OPTIONS (
  path "/Volumes/bootcamp_gabriel/landing/archivos/properties_raw.csv",
  header "true",
  inferSchema "true"
);

-- Ver resultado
SELECT * FROM bootcamp_gabriel.bronze.properties_bronze;
